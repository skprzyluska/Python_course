# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\stasi\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\stasi\.conda\envs\python_course_2024\lib\site-packages (from scikit-learn) (1.12.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.4.0-1-cp310-cp310-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 660.6 kB/s eta 0:00:16
#     --------------------------------------- 0.1/10.6 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/10.6 MB 2.3 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/10.6 MB 4.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.6 MB 7.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.6 MB 10.5 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.6 MB 15.0 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.6 MB 16.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.6 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.6 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 28.4 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    --------------------------------------- 302.2/302.2 kB 19.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.4.0 threadpoolctl-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('Salary_dataset.csv')
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
X = df['YearsExperience']
Y = df['Salary']

# %%
import matplotlib.pyplot as plt 
plt.scatter(X, Y)
plt.xlabel("Experience (years)")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Thats nice :)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=42)
X_test
# Out:
# 27     9.7
# 15     5.0
# 23     8.3
# 17     5.4
# 8      3.3
# 9      3.8
# 28    10.4
# 24     8.8
# 12     4.1
# 0      1.2
# 4      2.3
# 16     5.2
# Name: YearsExperience, dtype: float64

# %%
import numpy as np
X_train = np.array(X_train).reshape(-1, 1)
X_train
# Out:
# array([[ 3. ],
#        [ 4.2],
#        [ 4.1],
#        [ 8. ],
#        [ 1.4],
#        [ 1.6],
#        [ 9.1],
#        [ 2.1],
#        [ 7.2],
#        [ 9.6],
#        [ 6. ],
#        [10.6],
#        [ 6.9],
#        [ 3.3],
#        [ 4. ],
#        [ 4.6],
#        [ 6.1],
#        [ 3.1]])

# %%
X_test = np.array(X_test).reshape(-1, 1)
X_test
# Out:
# array([[ 9.7],
#        [ 5. ],
#        [ 8.3],
#        [ 5.4],
#        [ 3.3],
#        [ 3.8],
#        [10.4],
#        [ 8.8],
#        [ 4.1],
#        [ 1.2],
#        [ 2.3],
#        [ 5.2]])

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
C = lr.intercept_
print(f"Intercept: {C}")
m = lr.coef_
print(f"Coefficient: {m}")
# Out:
# Intercept: 25879.113578471923
# Coefficient: [9284.87835182]

# %%
Y_pred_train = lr.predict(X_train)
Y_pred_train
# Out:
# array([[ 53733.74863393],
#        [ 64875.60265611],
#        [ 63947.11482092],
#        [100158.14039301],
#        [ 38877.94327102],
#        [ 40734.91894138],
#        [110371.50658001],
#        [ 45377.35811729],
#        [ 92730.23771156],
#        [115013.94575592],
#        [ 81588.38368938],
#        [124298.82410774],
#        [ 89944.77420601],
#        [ 56519.21213947],
#        [ 63018.62698574],
#        [ 68589.55399683],
#        [ 82516.87152456],
#        [ 54662.23646911]])

# %%
import matplotlib.pyplot as plt
plt.scatter (X_train, Y_train)
plt.plot(X_train, Y_pred_train, color = 'violet')
plt.xlabel("Experience (years)")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Satisfying :)
# # Let's test it now:

# %%
Y_pred_test = lr.predict(X_test)
Y_pred_test
# Out:
# array([115942.4335911 ,  72303.50533756, 102943.60389856,  76017.45667829,
#         56519.21213947,  61161.65131538, 122441.84843738, 107586.04307447,
#         63947.11482092,  37020.96760065,  47234.33378765,  74160.48100792])

# %%
import matplotlib.pyplot as plt
plt.scatter (X_test, Y_test)
plt.plot(X_train, Y_pred_train, color = 'violet')
plt.xlabel("Experience (years)")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# Done :)
